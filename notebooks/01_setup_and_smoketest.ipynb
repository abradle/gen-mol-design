# %% [markdown]
# # 01 — Setup & Smoke Test
#
# Install the environment quickly.
#
# Run the cells below to confirm your environment.

# %%
# If you used pip: uncomment to install here
# !pip install -r ../requirements.txt

# %%
import sys, platform
print(platform.python_version(), platform.platform())
# Out:
# 3.12.2 macOS-15.1-arm64-arm-64bit

# %%
# Imports
import numpy as np, pandas as pd
import selfies as sf
from tqdm import tqdm

# RDKit imports
from rdkit import Chem
from rdkit.Chem import Crippen, rdMolDescriptors, AllChem, Draw
from rdkit import DataStructs

print("SELFIES:", sf.__version__)
print("RDKit OK:", Chem.MolFromSmiles("CCO") is not None)
# Out:
# SELFIES: 2.1.1
# RDKit OK: True

# %%
# Quick smoke test: compute logP for ethanol
mol = Chem.MolFromSmiles("CCO")
print("logP(ethanol) =", Crippen.MolLogP(mol))
# Out:
# logP(ethanol) = -0.0014000000000000123
